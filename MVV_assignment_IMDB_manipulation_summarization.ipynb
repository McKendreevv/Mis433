# %% [markdown]
# <a href="https://colab.research.google.com/github/McKendreevv/Mis433/blob/main/MVV_assignment_IMDB_manipulation_summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment - Analyzing the IMDB Top 1000 Movies

# %% [markdown]
# In the next few assignments, you will be working with this data set of IMDB top 1000 movies.
#
# Source: https://www.kaggle.com/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# To read the data file from your Google Drive, mount your drive first.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the data file "imdb_top_1000.csv" to a dataframe named "imdb"
imdb = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/imdb_top_1000.csv', header=0)
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
# Describe the dataframe using the info() method.
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
# List all the column names:
imdb.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# ## Part 1: Data Manipulation

# %%
# Display top 10 movies' title, released year and IMDB rating.
imdb[['Series_Title', 'Released_Year', 'IMDB_Rating']].head(10)
# Out:
#                                     Series_Title Released_Year  IMDB_Rating
# 0                       The Shawshank Redemption          1994          9.3
# 1                                  The Godfather          1972          9.2
# 2                                The Dark Knight          2008          9.0
# 3                         The Godfather: Part II          1974          9.0
# 4                                   12 Angry Men          1957          9.0
# 5  The Lord of the Rings: The Return of the King          2003          8.9
# 6                                   Pulp Fiction          1994          8.9
# 7                               Schindler's List          1993          8.9
# 8                                      Inception          2010          8.8
# 9                                     Fight Club          1999          8.8

# %%
# Display movies ranked 11-20.
# Show their title, released year and IMDB rating.
imdb[['Series_Title', 'Released_Year', 'IMDB_Rating']][11:21]
# Out:
#                                       Series_Title Released_Year  IMDB_Rating
# 11                                    Forrest Gump          1994          8.8
# 12                 Il buono, il brutto, il cattivo          1966          8.8
# 13           The Lord of the Rings: The Two Towers          2002          8.7
# 14                                      The Matrix          1999          8.7
# 15                                      Goodfellas          1990          8.7
# 16  Star Wars: Episode V - The Empire Strikes Back          1980          8.7
# 17                 One Flew Over the Cuckoo's Nest          1975          8.7
# 18                                        Hamilton          2020          8.6
# 19                                    Gisaengchung          2019          8.6
# 20                                 Soorarai Pottru          2020          8.6

# %%
# Select all movies directed by Quentin Tarantino.
# Show their title, released year, IMDB rating, and gross.
imdb.loc[imdb['Director'] == 'Quentin Tarantino', ['Series_Title', 'Released_Year', 'IMDB_Rating', 'Gross']]
# Out:
#                          Series_Title Released_Year  IMDB_Rating        Gross
# 6                        Pulp Fiction          1994          8.9  107,928,762
# 62                   Django Unchained          2012          8.4  162,805,434
# 93               Inglourious Basterds          2009          8.3  120,540,719
# 103                    Reservoir Dogs          1992          8.3    2,832,029
# 241                 Kill Bill: Vol. 1          2003          8.1   70,099,045
# 369                 Kill Bill: Vol. 2          2004          8.0   66,208,183
# 584                 The Hateful Eight          2015          7.8   54,117,416
# 879  Once Upon a Time... in Hollywood          2019          7.6  142,502,728

# %%
# Select all R rated movies with IMDB_Rating>=8.5
# Show their title, released year, certificate, and IMDB rating.
imdb.loc[(imdb['Certificate'] == 'R') & (imdb['IMDB_Rating'] >= 8.5), ['Series_Title', 'Released_Year', 'Certificate', 'IMDB_Rating']]
# Out:
#            Series_Title Released_Year Certificate  IMDB_Rating
# 24  Saving Private Ryan          1998           R          8.6
# 38          The Pianist          2002           R          8.5
# 40   American History X          1998           R          8.5

# %%
# How many unique values are there in the column "Released_Year"?
# Hint: nunique()
imdb['Released_Year'].nunique()
# Out:
# 100

# %%
# Count the number of movies in each "Released_Year"?
# Hint: value_counts()
imdb['Released_Year'].value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1920     1
# 1930     1
# 1922     1
# 1943     1
# PG       1
# Name: count, Length: 100, dtype: int64

# %%
# In this dataset, there is a movie with an error in "Released_Year".
# Hint: Released_Year should be a 4-digit integer but this movie's is not.
# Find this movie.
imdb.loc[imdb['Released_Year'] == 'PG']
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
# Correct the values for the corresponding columns ("Released_Year" and "Certificate").
# You may want to look up this movie on www.imdb.com.
# Hint: You can set value for a particular row by: df.loc[row_name, column_name] = new_value
imdb.loc[966, 'Released_Year'] = [1995]
imdb.loc[966, 'Certificate'] = 'PG_13'

# %%
# Change the data type of "Released_Year" to int
imdb['Released_Year'] = imdb['Released_Year'].astype(int)

# %%
# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, certificate, and IMDB rating.
imdb.loc[(imdb['Released_Year'] >= 2010) & (imdb['IMDB_Rating'] >= 8.5), ['Series_Title', 'Released_Year', 'Certificate', 'IMDB_Rating']]
# Out:
#         Series_Title  Released_Year Certificate  IMDB_Rating
# 8          Inception           2010          UA          8.8
# 18          Hamilton           2020       PG-13          8.6
# 19      Gisaengchung           2019           A          8.6
# 20   Soorarai Pottru           2020           U          8.6
# 21      Interstellar           2014          UA          8.6
# 33             Joker           2019           A          8.5
# 34          Whiplash           2014           A          8.5
# 35  The Intouchables           2011          UA          8.5

# %%
# Select all movies whose genres contain 'Animation'
imdb.loc[imdb['Genre'].str.contains('Animation', na=False)]
# Out:
#                                            Poster_Link  \
# 23   https://m.media-amazon.com/images/M/MV5BMjlmZm...
# 43   https://m.media-amazon.com/images/M/MV5BYTYxNG...
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...
# 56   https://m.media-amazon.com/images/M/MV5BODRmZD...
# 58   https://m.media-amazon.com/images/M/MV5BMjMwND...
# ..                                                 ...
# 956  https://m.media-amazon.com/images/M/MV5BODkxNG...
# 971  https://m.media-amazon.com/images/M/MV5BMTY5Nj...
# 976  https://m.media-amazon.com/images/M/MV5BN2JlZT...
# 986  https://m.media-amazon.com/images/M/MV5BMzZiOD...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
#
#                           Series_Title  Released_Year Certificate  Runtime  \
# 23       Sen to Chihiro no kamikakushi           2001           U  125 min
# 43                       The Lion King           1994           U   88 min
# 46                      Hotaru no haka           1988           U   89 min
# 56                      Kimi no na wa.           2016           U  106 min
# 58   Spider-Man: Into the Spider-Verse           2018           U  117 min
# ..                                 ...            ...         ...      ...
# 956                              Mulan           1998           U   88 min
# 971                  Omohide poro poro           1991           U  118 min
# 976                 The Little Mermaid           1989           U   83 min
# 986                     Watership Down           1978           U   91 min
# 992                    The Jungle Book           1967           U   78 min
#
#                             Genre  IMDB_Rating  \
# 23   Animation, Adventure, Family          8.6
# 43    Animation, Adventure, Drama          8.5
# 46          Animation, Drama, War          8.5
# 56      Animation, Drama, Fantasy          8.4
# 58   Animation, Action, Adventure          8.4
# ..                            ...          ...
# 956  Animation, Adventure, Family          7.6
# 971     Animation, Drama, Romance          7.6
# 976    Animation, Family, Fantasy          7.6
# 986   Animation, Adventure, Drama          7.6
# 992  Animation, Adventure, Family          7.6
#
#                                               Overview  Meta_score  \
# 23   During her family's move to the suburbs, a sul...        96.0
# 43   Lion prince Simba and his father are targeted ...        88.0
# 46   A young boy and his little sister struggle to ...        94.0
# 56   Two strangers find themselves linked in a biza...        79.0
# 58   Teen Miles Morales becomes the Spider-Man of h...        87.0
# ..                                                 ...         ...
# 956  To save her father from death in the army, a y...        71.0
# 971  A twenty-seven-year-old office worker travels ...        90.0
# 976  A mermaid princess makes a Faustian bargain in...        88.0
# 986  Hoping to escape destruction by human develope...        64.0
# 992  Bagheera the Panther and Baloo the Bear have a...        65.0
#
#                 Director             Star1               Star2  \
# 23        Hayao Miyazaki     Daveigh Chase   Suzanne Pleshette
# 43          Roger Allers       Rob Minkoff   Matthew Broderick
# 46         Isao Takahata   Tsutomu Tatsumi     Ayano Shiraishi
# 56        Makoto Shinkai  Ryûnosuke Kamiki  Mone Kamishiraishi
# 58       Bob Persichetti      Peter Ramsey      Rodney Rothman
# ..                   ...               ...                 ...
# 956        Tony Bancroft        Barry Cook         Ming-Na Wen
# 971        Isao Takahata         Miki Imai    Toshirô Yanagiba
# 976         Ron Clements       John Musker         Jodi Benson
# 986         Martin Rosen       John Hubley           John Hurt
# 992  Wolfgang Reitherman       Phil Harris     Sebastian Cabot
#
#                 Star3              Star4  No_of_Votes        Gross
# 23         Miyu Irino       Rumi Hiiragi     651376.0   10,055,859
# 43       Jeremy Irons   James Earl Jones     942045.0  422,783,777
# 46    Akemi Yamaguchi  Yoshiko Shinohara     235231.0          NaN
# 56         Ryô Narita           Aoi Yûki     194838.0    5,017,246
# 58      Shameik Moore       Jake Johnson     375110.0  190,241,310
# ..                ...                ...          ...          ...
# 956      Eddie Murphy            BD Wong     256906.0  120,620,254
# 971        Yoko Honna       Mayumi Izuka      27071.0      453,243
# 976  Samuel E. Wright   Rene Auberjonois     237696.0  111,543,479
# 986    Richard Briers   Ralph Richardson      33656.0          NaN
# 992       Louis Prima   Bruce Reitherman     166409.0  141,843,612
#
# [82 rows x 16 columns]

# %%
# Create a new dataframe called "stars" including the following columns:
# Series_Title, Released_Year, Star1, Star2, Star3, Star4
stars = imdb[['Series_Title', 'Released_Year', 'Star1', 'Star2', 'Star3', 'Star4']]
stars.head()
# Out:
#                Series_Title  Released_Year           Star1           Star2  \
# 0  The Shawshank Redemption           1994     Tim Robbins  Morgan Freeman
# 1             The Godfather           1972   Marlon Brando       Al Pacino
# 2           The Dark Knight           2008  Christian Bale    Heath Ledger
# 3    The Godfather: Part II           1974       Al Pacino  Robert De Niro
# 4              12 Angry Men           1957     Henry Fonda     Lee J. Cobb
#
#            Star3           Star4
# 0     Bob Gunton  William Sadler
# 1     James Caan    Diane Keaton
# 2  Aaron Eckhart   Michael Caine
# 3  Robert Duvall    Diane Keaton
# 4  Martin Balsam    John Fiedler

# %%
# Create a new dataframe called "genres" including the following columns:
# Series_Title, Released_Year, Genre.
genres = imdb[['Series_Title', 'Released_Year', 'Genre']]
genres.head()
# Out:
#                Series_Title  Released_Year                 Genre
# 0  The Shawshank Redemption           1994                 Drama
# 1             The Godfather           1972          Crime, Drama
# 2           The Dark Knight           2008  Action, Crime, Drama
# 3    The Godfather: Part II           1974          Crime, Drama
# 4              12 Angry Men           1957          Crime, Drama

# %%
# Sorting:
# Sort dataframe genres in ascending order of "Released_Year"
genres.sort_values(by='Released_Year')
# Out:
#                      Series_Title  Released_Year                         Genre
# 321  Das Cabinet des Dr. Caligari           1920      Fantasy, Horror, Mystery
# 127                       The Kid           1921         Comedy, Drama, Family
# 568                     Nosferatu           1922               Fantasy, Horror
# 194                  Sherlock Jr.           1924       Action, Comedy, Romance
# 193                 The Gold Rush           1925      Adventure, Comedy, Drama
# ..                            ...            ...                           ...
# 205                          Soul           2020  Animation, Adventure, Comedy
# 612    The Trial of the Chicago 7           2020      Drama, History, Thriller
# 613                          Druk           2020                 Comedy, Drama
# 18                       Hamilton           2020     Biography, Drama, History
# 20                Soorarai Pottru           2020                         Drama
#
# [1001 rows x 3 columns]

# %%
# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, Certificate, and gross.
# Sort them in descending order of "Gross"
imdb.loc[(imdb['Released_Year'] >= 2010) & (imdb['IMDB_Rating'] >= 8.5), ['Series_Title', 'Released_Year', 'Certificate', 'Gross']].sort_values(by='Gross', ascending=False)
# Out:
#         Series_Title  Released_Year Certificate        Gross
# 19      Gisaengchung           2019           A   53,367,844
# 33             Joker           2019           A  335,451,311
# 8          Inception           2010          UA  292,576,195
# 21      Interstellar           2014          UA  188,020,017
# 35  The Intouchables           2011          UA   13,182,281
# 34          Whiplash           2014           A   13,092,000
# 18          Hamilton           2020       PG-13          NaN
# 20   Soorarai Pottru           2020           U          NaN

# %%
# Does the sorting result look right to you? What's the problem?
#several NaN values

# %%
# Resolve this problem of "Gross" and convert its data type to float
# Hint: You may find this webpage useful:
# https://stackoverflow.com/questions/28986489/how-to-replace-text-in-a-column-of-a-pandas-dataframe
# Convert to string first to handle NaN values gracefully, then remove commas, then convert to numeric.
imdb['Gross'] = imdb['Gross'].astype(str).str.replace(',', '')
imdb['Gross'] = pd.to_numeric(imdb['Gross'], errors='coerce') # 'coerce' will turn 'nan' strings into actual NaN floats

# %%
# Next, redo the sorting on Gross

# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, Certificate, and gross.
# Sort them in descending order of "Gross"
imdb.loc[(imdb['Released_Year'] >= 2010) & (imdb['IMDB_Rating'] >= 8.5), ['Series_Title', 'Released_Year', 'Certificate', 'Gross']].sort_values(by='Gross', ascending=False)
# Out:
#         Series_Title  Released_Year Certificate        Gross
# 33             Joker           2019           A  335451311.0
# 8          Inception           2010          UA  292576195.0
# 21      Interstellar           2014          UA  188020017.0
# 19      Gisaengchung           2019           A   53367844.0
# 35  The Intouchables           2011          UA   13182281.0
# 34          Whiplash           2014           A   13092000.0
# 18          Hamilton           2020       PG-13          NaN
# 20   Soorarai Pottru           2020           U          NaN

# %%
# Add a new column "Runtime_min" by removing the substring " min" in "Runtime"
# Set its data type as int
# Hint: https://stackoverflow.com/questions/36505847/substring-of-an-entire-column-in-pandas-dataframe
imdb['Runtime_min'] = (
    imdb['Runtime']
    .str.replace(' min', '', regex=False)
    .astype(float)
    .fillna(0)
    .astype(int)
)
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A  142 min
# 1             The Godfather           1972           A  175 min
# 2           The Dark Knight           2008          UA  152 min
# 3    The Godfather: Part II           1974           A  202 min
# 4              12 Angry Men           1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross  Runtime_min
# 0  William Sadler    2343110.0   28341469.0          142
# 1    Diane Keaton    1620367.0  134966411.0          175
# 2   Michael Caine    2303232.0  534858444.0          152
# 3    Diane Keaton    1129952.0   57300000.0          202
# 4    John Fiedler     689845.0    4360000.0           96

# %%
# Add a new column "Age_Year" by expression: Current year - Released_Year
imdb['Age_Year'] = 2026 - imdb['Released_Year']
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A  142 min
# 1             The Godfather           1972           A  175 min
# 2           The Dark Knight           2008          UA  152 min
# 3    The Godfather: Part II           1974           A  202 min
# 4              12 Angry Men           1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross  Runtime_min  Age_Year
# 0  William Sadler    2343110.0   28341469.0          142        32
# 1    Diane Keaton    1620367.0  134966411.0          175        54
# 2   Michael Caine    2303232.0  534858444.0          152        18
# 3    Diane Keaton    1129952.0   57300000.0          202        52
# 4    John Fiedler     689845.0    4360000.0           96        69

# %%
# Add a new column "Decade" with values as 1980, 1990, 2000, 2010, 2020, etc.
imdb['Decade'] = (imdb['Released_Year'] // 10) * 10
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A  142 min
# 1             The Godfather           1972           A  175 min
# 2           The Dark Knight           2008          UA  152 min
# 3    The Godfather: Part II           1974           A  202 min
# 4              12 Angry Men           1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross  Runtime_min  Age_Year  Decade
# 0  William Sadler    2343110.0   28341469.0          142        32    1990
# 1    Diane Keaton    1620367.0  134966411.0          175        54    1970
# 2   Michael Caine    2303232.0  534858444.0          152        18    2000
# 3    Diane Keaton    1129952.0   57300000.0          202        52    1970
# 4    John Fiedler     689845.0    4360000.0           96        69    1950

# %% [markdown]
# ## Part 2: Data Summarization

# %%
# Total "Gross" of all top 1000 movies
imdb['Gross'].sum()
# Out:
# np.float64(56536877976.0)

# %%
# Average "No_of_Votes" of all movies
imdb['No_of_Votes'].mean()
# Out:
# np.float64(273692.911)

# %%
# Count movies in each decade (e.g., ..., 1980, 1990, 2000, 2010, 2020)
# Sort decades by the number of movies in descending order
imdb['Decade'].value_counts().sort_index(ascending=False)
# Out:
# Decade
# 2020      6
# 2010    242
# 2000    237
# 1990    152
# 1980     89
# 1970     76
# 1960     73
# 1950     56
# 1940     35
# 1930     24
# 1920     11
# Name: count, dtype: int64

# %%
# Count movies by different directors.
# Show the top 10 directors with the most movies in this list
imdb.groupby('Director')['Series_Title'].count().sort_values(ascending=False).head(10)
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Martin Scorsese     10
# Akira Kurosawa      10
# Stanley Kubrick      9
# Woody Allen          9
# Billy Wilder         9
# David Fincher        8
# Clint Eastwood       8
# Name: Series_Title, dtype: int64

# %%
# For each director, calculate the number of movies, average IMDB_Rating, and total gross.
# Ranked in descending order of total gross
# Show the top 10 directors with the most gross
imdb.groupby('Director').agg({'Series_Title': 'count', 'IMDB_Rating': 'mean', 'Gross': 'sum'}).sort_values(by='Gross', ascending=False).head(10)
# Out:
#                    Series_Title  IMDB_Rating         Gross
# Director
# Steven Spielberg             13     8.030769  2.478133e+09
# Anthony Russo                 4     8.075000  2.205039e+09
# Christopher Nolan             8     8.462500  1.937454e+09
# James Cameron                 5     8.080000  1.748237e+09
# Peter Jackson                 5     8.400000  1.597312e+09
# J.J. Abrams                   3     7.833333  1.423171e+09
# Brad Bird                     4     7.900000  1.099628e+09
# Robert Zemeckis               5     8.120000  1.049446e+09
# David Yates                   3     7.800000  9.789537e+08
# Pete Docter                   4     8.125000  9.393821e+08

# %%
# Group movies by decade and director
# In each group (i.e., for each decade and each director),
# calculate the number of movies and average IMDB rating.
# Sort in descending order of movie count
imdb.groupby(['Decade', 'Director']).agg({'Series_Title': 'count', 'IMDB_Rating': 'mean'}).sort_values(by='Series_Title', ascending=False)
# Out:
#                              Series_Title  IMDB_Rating
# Decade Director
# 1950   Billy Wilder                     6     8.133333
#        Akira Kurosawa                   5     8.260000
# 2010   Denis Villeneuve                 5     7.980000
# 1950   Alfred Hitchcock                 5     8.220000
# 1980   Steven Spielberg                 5     7.980000
# ...                                   ...          ...
# 2010   Tyler Nilson                     1     7.600000
#        Umesh Shukla                     1     8.100000
#        Vikas Bahl                       1     8.200000
#        Vikramaditya Motwane             1     8.200000
#        Vishal Bhardwaj                  1     8.100000
#
# [749 rows x 2 columns]

# %%
# Find the top 3 highest rated movies of each year since 2010.
# Show their released year, ranking, title, and IMDB_Rating.
# Sort them in descending order of year and ascending order of ranking
# 727         What We Do in the Shadows           2014           R   86 min
# 897                         Philomena           2013       PG-13   98 min
# 734                    La vie d'Adèle           2013           A  180 min
# 735                       Kai po che!           2013           U  130 min
# 899                         El cuerpo           2012         NaN  112 min
# 901                      End of Watch           2012           A  109 min
# 736       The Broken Circle Breakdown           2012         NaN  111 min
# 900                      Serbuan maut           2011           A  101 min
# 907                             50/50           2011           R  100 min
# 910                         Moneyball           2011       PG-13  133 min
# 902           Kari-gurashi no Arietti           2010           U   94 min
# 904                         True Grit           2010       PG-13  110 min
# 905                            Hævnen           2010           R  118 min
#
#                             Genre  IMDB_Rating  \
# 612      Drama, History, Thriller          7.8
# 613                 Comedy, Drama          7.8
# 464        Comedy, Drama, Romance          7.9
# 877     Biography, Drama, History          7.6
# 879                 Comedy, Drama          7.6
# 882       Biography, Crime, Drama          7.6
# 878      Drama, Mystery, Thriller          7.6
# 891  Animation, Action, Adventure          7.6
# 903         Drama, Music, Romance          7.6
# 880                         Drama          7.6
# 881                         Drama          7.6
# 883                         Drama          7.6
# 892  Animation, Adventure, Comedy          7.6
# 896          Action, Crime, Drama          7.6
# 572                         Drama          7.8
# 885         Crime, Drama, Romance          7.6
# 886                         Drama          7.6
# 890      Drama, History, Thriller          7.6
# 895                  Crime, Drama          7.6
# 898      Action, Adventure, Drama          7.6
# 727                Comedy, Horror          7.7
# 897      Biography, Comedy, Drama          7.6
# 734                Drama, Romance          7.7
# 735                  Drama, Sport          7.7
# 899             Mystery, Thriller          7.6
# 901          Action, Crime, Drama          7.6
# 736         Drama, Music, Romance          7.7
# 900              Action, Thriller          7.6
# 907        Comedy, Drama, Romance          7.6
# 910       Biography, Drama, Sport          7.6
# 902  Animation, Adventure, Family          7.6
# 904                Drama, Western          7.6
# 905                Drama, Romance          7.6
#
#                                               Overview  Meta_score  \
# 612  The story of 7 people on trial stemming from v...        77.0
# 613  Four friends, all high school teachers, test a...        81.0
# 464  The emotional journey of two hopelessly in lov...         NaN
# 877  A corporate defense attorney takes on an envir...        73.0
# 879  A faded television actor and his stunt double ...        83.0
# 882  World-renowned civil rights defense attorney B...        68.0
# 878  After his teenage daughter goes missing, a des...        71.0
# 891  The Incredibles family takes on a new mission ...        80.0
# 903  A musician helps a young singer find fame as a...        88.0
# 880  A couple going through a divorce must team up ...        86.0
# 881  Set over one summer, the film follows precocio...        92.0
# 883  Frank, a single man raising his child prodigy ...        60.0
# 892  In Ancient Polynesia, when a terrible curse in...        81.0
# 896  A divorced father and his ex-con older brother...        88.0
# 572  While both participating in a production of "D...        85.0
# 885  A young Spanish woman who has recently moved t...        77.0
# 886  When five orphan girls are seen innocently pla...        83.0
# 890  During the Cold War, an American lawyer is rec...        81.0
# 895  In a Russian coastal town, Kolya is forced to ...        92.0
# 898  A growing nation of genetically evolved apes l...        79.0
# 727  Viago, Deacon and Vladislav are vampires who a...        76.0
# 897  A world-weary political journalist picks up th...        77.0
# 734  Adèle's life is changed when she meets Emma, a...        89.0
# 735  Three friends growing up in India at the turn ...        40.0
# 899  A detective searches for the body of a femme f...         NaN
# 901  Shot documentary-style, this film follows the ...        68.0
# 736  Elise and Didier fall in love at first sight, ...        70.0
# 892        Chris Williams         Auli'i Cravalho     272784.0  248757044.0
# 896          Jeff Bridges          Gil Birmingham     204175.0   26862450.0
# 572          Babak Karimi             Mina Sadati      51240.0    2402067.0
# 885        Franz Rogowski             Burak Yigit      52903.0          NaN
# 886      Tugba Sunguroglu              Elit Iscan      35785.0     845464.0
# 890             Alan Alda                Amy Ryan     287659.0   72313754.0
# 895        Roman Madyanov   Vladimir Vdovichenkov      49397.0    1092800.0
# 898           Andy Serkis        Kodi Smit-McPhee     411599.0  208545589.0
# 727         Taika Waititi    Cori Gonzalez-Macuer     157498.0    3333000.0
# 897  Sophie Kennedy Clark         Mare Winningham      94212.0   37707719.0
# 734      Salim Kechiouche        Aurélien Recoing     138741.0    2199675.0
# 735         Rajkummar Rao             Amrita Puri      32628.0    1122527.0
# 899           Belén Rueda            Aura Garrido      57549.0          NaN
# 901         Anna Kendrick         America Ferrera     228132.0   41003371.0
# 736        Nell Cattrysse    Geert Van Rampelberg      39379.0     175058.0
# 900          Ray Sahetapy          Donny Alamsyah     190531.0    4105123.0
# 907         Anna Kendrick     Bryce Dallas Howard     315426.0   35014192.0
# 910            Jonah Hill  Philip Seymour Hoffman     369529.0   75605492.0
# 902      Ryûnosuke Kamiki        Tatsuya Fujiwara      80939.0   19202743.0
# 904            Matt Damon        Hailee Steinfeld     311822.0  171243005.0
# 905        Markus Rygaard             Wil Johnson      38491.0    1008098.0
#
#      Runtime_min  Age_Year  Decade
# 612          129         6    2020
# 613          117         6    2020
# 464          101         6    2020
# 877          126         7    2010
# 879          161         7    2010
# 882          137         7    2010
# 878          102         8    2010
# 891          118         8    2010
# 903          136         8    2010
# 880          127         9    2010
# 881          111         9    2010
# 883          101         9    2010
# 892          107        10    2010
# 896          102        10    2010
# 572          124        10    2010
# 885          138        11    2010
# 886           97        11    2010
# 890          142        11    2010
# 895          140        12    2010
# 898          130        12    2010
# 727           86        12    2010
# 897           98        13    2010
# 734          180        13    2010
# 735          130        13    2010
# 899          112        14    2010
# 901          109        14    2010
# 736          111        14    2010
# 900          101        15    2010
# 907          100        15    2010
# 910          133        15    2010
# 902           94        16    2010
# 904          110        16    2010
# 905          118        16    2010

# %%
# Find all directors whose movies appeared in at least five different decades.
# Your result should include: director, decade, and the number of movies in the decade.
imdb.groupby(['Director', 'Decade']).agg({'Series_Title': 'count'}).loc[imdb.groupby(['Director', 'Decade']).agg({'Series_Title': 'count'})['Series_Title'] >= 5]
# Out:
#                          Series_Title
# Director         Decade
# Akira Kurosawa   1950               5
# Alfred Hitchcock 1940               5
#                  1950               5
# Billy Wilder     1950               6
# Clint Eastwood   2000               5
# Denis Villeneuve 2010               5
# Steven Spielberg 1980               5

# %%
# Ask two questions about this dataset and write your code to answer them.
# Question 1: What Decades contain the most movies
imdb.groupby('Decade').agg({'Series_Title': 'count'}).sort_values(by='Series_Title', ascending=False)
# Out:
#         Series_Title
# Decade
# 2010             242
# 2000             237
# 1990             151
# 1980              89
# 1970              76
# 1960              73
# 1950              56
# 1940              35
# 1930              24
# 1920              11
# 2020               6

# %%
# Questions 2: What was the most underrated movie
imdb.loc[imdb['IMDB_Rating'] == imdb['IMDB_Rating'].min()]
# Out:
#                                            Poster_Link  \
# 877  https://m.media-amazon.com/images/M/MV5BODQ0M2...
# 878  https://m.media-amazon.com/images/M/MV5BMjIwOT...
# 879  https://m.media-amazon.com/images/M/MV5BOTg4ZT...
# 880  https://m.media-amazon.com/images/M/MV5BNzk2Nm...
# 881  https://m.media-amazon.com/images/M/MV5BMjg4Zm...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#